# %% [markdown]
# # Assignment 1 - Group 2

# %%
import nltk

# %%
from nltk.corpus import PlaintextCorpusReader
corpus_root = "C:/Users/cjlim/CheryseLING250/assignment1/"

# %%
corpus_root
# Out:
# 'C:/Users/cjlim/CheryseLING250/assignment1/'

# %%
pwd
# Out:
# 'C:\\Users\\cjlim\\CheryseLING250\\assignment1'

# %% [markdown]
# This corpus contains a variety of texts.

# %%
text = PlaintextCorpusReader(corpus_root, '.*', encoding = "utf8")

# %%
shortstory = text.words('PartyGirls.txt')

# %%
newsarticle = text.words('PretendianInvestigation.txt')

# %%
shortstory
# Out:
# ['Party', 'Girls', 'A', 'short', 'story', 'by', ...]

# %%
newsarticle
# Out:
# ['The', 'Curious', 'Case', 'of', 'Gina', 'Adams', ':', ...]

# %% [markdown]
# ## 1. Length

# %%
len(shortstory)
# Out:
# 13733

# %%
len(newsarticle)
# Out:
# 8756

# %% [markdown]
# ## 2. Lexical Diversity

# %% [markdown]
# ##### Party Girls

# %%
set(shortstory)
# Out:
# {'side',
#  'love',
#  'Trying',
#  'scheme',
#  'wondering',
#  'gaze',
#  'eyes',
#  'isn',
#  'doesn',
#  'Unfortunately',
#  'details',
#  'claiming',
#  'clock',
#  'fact',
#  'kisses',
#  'slower',
#  'ahead',
#  'angry',
#  'Must',
#  'tired',
#  'friends',
#  'expect',
#  'quietly',
#  'classified',
#  'promised',
#  'must',
#  'works',
#  'academic',
#  'business',
#  'heck',
#  'liked',
#  'biggest',
#  'disappointment',
#  'areas',
#  'classroom',
#  'entering',
#  'by',
#  'leaves',
#  'romantic',
#  'kiss',
#  'joy',
#  'amazed',
#  'Raine',
#  'point',
#  'thank',
#  'grumpy',
#  'will',
#  'staring',
#  'admit',
#  'house',
#  'everyone',
#  '.?”',
#  'thumb',
#  've',
#  'bloody',
#  'onset',
#  'tone',
#  'repeats',
#  'chin',
#  'least',
#  'glitter',
#  'window',
#  'both',
#  'before',
#  'plan',
#  'wife',
#  'meeting',
#  'From',
#  'October',
#  'old',
#  'hysterical',
#  'heels',
#  'recognise',
#  'period',
#  'make',
#  'changed',
#  'chatting',
#  'five',
# ...

# %%
sorted(set(shortstory))
# Out:
# ['!',
#  '!?',
#  '!?”',
#  '!”',
#  '(',
#  '),',
#  ',',
#  ',”',
#  '-',
#  '-”',
#  '.',
#  '.?”',
#  '.”',
#  '/',
#  '11pm',
#  '1pm',
#  '4am',
#  '99',
#  '?',
#  '?”',
#  'A',
#  'ALLEN',
#  'About',
#  'Academy',
#  'After',
#  'Ain',
#  'Alice',
#  'All',
#  'Allen',
#  'And',
#  'Another',
#  'Anyway',
#  'Are',
#  'As',
#  'At',
#  'August',
#  'BECKY',
#  'Bar',
#  'Barely',
#  'Because',
#  'Becca',
#  'Becky',
#  'Before',
#  'Bex',
#  'Bisexual',
#  'Bit',
#  'Brooklyn',
#  'Burgundy',
#  'But',
#  'Can',
#  'Careless',
#  'Carys',
#  'Cinema',
#  'City',
#  'Classic',
#  'Come',
#  'Cor',
#  'Could',
#  'Crown',
#  'Cute',
#  'Cyrus',
#  'D',
#  'Damn',
#  'Darling',
#  'Debra',
#  'December',
#  'Did',
#  'Different',
#  'Do',
#  'Doesn',
#  'Don',
#  'Drag',
#  'Dreams',
#  'Dressed',
#  'Drowns',
#  'Dude',
#  'Durham',
#  'Edmonds',
#  'Eighteen',
#  'Er',
#  'Erm',
#  'Essentially',
#  'Eve',
#  'Even',
#  'Eventually',
#  'Every',
#  'Everything',
# ...

# %%
sorted(set(w.lower() for w in shortstory))
# Out:
# ['!',
#  '!?',
#  '!?”',
#  '!”',
#  '(',
#  '),',
#  ',',
#  ',”',
#  '-',
#  '-”',
#  '.',
#  '.?”',
#  '.”',
#  '/',
#  '11pm',
#  '1pm',
#  '4am',
#  '99',
#  '?',
#  '?”',
#  'a',
#  'able',
#  'about',
#  'above',
#  'absolutely',
#  'academic',
#  'academy',
#  'accent',
#  'achiever',
#  'across',
#  'actual',
#  'actually',
#  'admin',
#  'admit',
#  'adorable',
#  'adult',
#  'advice',
#  'afar',
#  'afresh',
#  'after',
#  'afternoon',
#  'again',
#  'against',
#  'age',
#  'aged',
#  'ages',
#  'ago',
#  'agree',
#  'ahead',
#  'ain',
#  'air',
#  'alarm',
#  'alcohol',
#  'alcoholism',
#  'alice',
#  'all',
#  'allen',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'always',
#  'am',
#  'amazed',
#  'amazement',
#  'amazing',
#  'amusedly',
#  'an',
#  'and',
#  'angry',
#  'angst',
#  'announce',
#  'annoyed',
#  'annoys',
#  'another',
#  'answer',
#  'any',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'apart',
# ...

# %%
sorted(set(w.lower() for w in shortstory if w.isalpha()))
# Out:
# ['a',
#  'able',
#  'about',
#  'above',
#  'absolutely',
#  'academic',
#  'academy',
#  'accent',
#  'achiever',
#  'across',
#  'actual',
#  'actually',
#  'admin',
#  'admit',
#  'adorable',
#  'adult',
#  'advice',
#  'afar',
#  'afresh',
#  'after',
#  'afternoon',
#  'again',
#  'against',
#  'age',
#  'aged',
#  'ages',
#  'ago',
#  'agree',
#  'ahead',
#  'ain',
#  'air',
#  'alarm',
#  'alcohol',
#  'alcoholism',
#  'alice',
#  'all',
#  'allen',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'always',
#  'am',
#  'amazed',
#  'amazement',
#  'amazing',
#  'amusedly',
#  'an',
#  'and',
#  'angry',
#  'angst',
#  'announce',
#  'annoyed',
#  'annoys',
#  'another',
#  'answer',
#  'any',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'apart',
#  'apologising',
#  'apparently',
#  'apparition',
#  'appealing',
#  'appear',
#  'apprenticeship',
#  'approach',
#  'approached',
#  'approving',
#  'approvingly',
#  'are',
#  'areas',
# ...

# %% [markdown]
# ##### Pretendian Investigation

# %%
set(newsarticle)
# Out:
# {'news',
#  'navigate',
#  'witnessed',
#  'prepared',
#  'wondering',
#  'died',
#  'demonstrated',
#  'invitation',
#  'isn',
#  'accusation',
#  'barn',
#  'claiming',
#  'details',
#  'alumnus',
#  'clear',
#  'fact',
#  'investigating',
#  'certificates',
#  'rise',
#  'forums',
#  'slower',
#  'communities',
#  'baffling',
#  'foster',
#  'expect',
#  'reinforce',
#  'wished',
#  'must',
#  'monitored',
#  'academic',
#  'glacial',
#  'authority',
#  'identity',
#  'nor',
#  'Weeks',
#  'business',
#  'liked',
#  'Indigenizing',
#  'disappointment',
#  'classroom',
#  'by',
#  'accomplishments',
#  'Helen',
#  'sweater',
#  'Cluster',
#  'Shannon',
#  'clean',
#  'tenure',
#  'performance',
#  'emphasizing',
#  'conversations',
#  'point',
#  'Journal',
#  'graduate',
#  'parent',
#  'non',
#  'will',
#  'admit',
#  'accused',
#  'market',
#  'equivalent',
#  'tangled',
#  'everyone',
#  'lengthy',
#  've',
#  'per',
#  'Families',
#  'individual',
#  'identified',
# ...

# %%
sorted(set(newsarticle))
# Out:
# ['!”',
#  '$',
#  '(',
#  ')',
#  '),',
#  ').',
#  '***',
#  ',',
#  ',”',
#  '-',
#  '.',
#  '.)',
#  '.,',
#  '.’',
#  '.’”',
#  '.”',
#  '000',
#  '1',
#  '10',
#  '100',
#  '13',
#  '14',
#  '16',
#  '1879',
#  '19',
#  '1900',
#  '1906',
#  '1920',
#  '1930',
#  '1940',
#  '1980s',
#  '19th',
#  '20',
#  '2005',
#  '2006',
#  '2007',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '20s',
#  '20th',
#  '210',
#  '23andMe',
#  '3',
#  '30',
#  '35',
#  '367',
#  '400',
#  '410',
#  '500',
#  '50s',
#  '5th',
#  '6',
#  '67',
#  '70s',
#  '74',
#  '94',
#  ':',
#  ';',
#  '?',
#  '?”',
#  'A',
#  'Aboriginal',
#  'About',
#  'According',
#  'Act',
#  'Adams',
#  'After',
#  'Afterwards',
#  'Albert',
#  'Algonquin',
#  'Algonquins',
#  'Alleged',
#  'Although',
#  'American',
#  'Amie',
#  'Among',
#  'Ancestry',
#  'And',
#  'Anishinaabe',
#  'Anishinaabeg',
#  'Anishinaabemowin',
#  'Anishinabeg',
#  'Another',
#  'Appropriating',
# ...

# %%
sorted(set(w.lower() for w in newsarticle))
# Out:
# ['!”',
#  '$',
#  '(',
#  ')',
#  '),',
#  ').',
#  '***',
#  ',',
#  ',”',
#  '-',
#  '.',
#  '.)',
#  '.,',
#  '.’',
#  '.’”',
#  '.”',
#  '000',
#  '1',
#  '10',
#  '100',
#  '13',
#  '14',
#  '16',
#  '1879',
#  '19',
#  '1900',
#  '1906',
#  '1920',
#  '1930',
#  '1940',
#  '1980s',
#  '19th',
#  '20',
#  '2005',
#  '2006',
#  '2007',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '20s',
#  '20th',
#  '210',
#  '23andme',
#  '3',
#  '30',
#  '35',
#  '367',
#  '400',
#  '410',
#  '500',
#  '50s',
#  '5th',
#  '6',
#  '67',
#  '70s',
#  '74',
#  '94',
#  ':',
#  ';',
#  '?',
#  '?”',
#  'a',
#  'aaniin',
#  'abduction',
#  'aboriginal',
#  'about',
#  'absence',
#  'academic',
#  'accepted',
#  'access',
#  'acclaimed',
#  'accompanies',
#  'accomplishments',
#  'according',
#  'account',
#  'accountability',
#  'accounts',
#  'accusation',
#  'accusations',
#  'accused',
#  'accusing',
#  'acknowledge',
#  'acknowledgement',
# ...

# %%
sorted(set(w.lower() for w in newsarticle if w.isalpha()))
# Out:
# ['a',
#  'aaniin',
#  'abduction',
#  'aboriginal',
#  'about',
#  'absence',
#  'academic',
#  'accepted',
#  'access',
#  'acclaimed',
#  'accompanies',
#  'accomplishments',
#  'according',
#  'account',
#  'accountability',
#  'accounts',
#  'accusation',
#  'accusations',
#  'accused',
#  'accusing',
#  'acknowledge',
#  'acknowledgement',
#  'across',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'active',
#  'actively',
#  'adamant',
#  'adams',
#  'adding',
#  'address',
#  'addressing',
#  'adjunct',
#  'administration',
#  'administrators',
#  'admission',
#  'admit',
#  'admitted',
#  'adopted',
#  'advance',
#  'advise',
#  'advisor',
#  'advisory',
#  'affected',
#  'affiliations',
#  'affirm',
#  'affirmation',
#  'affirmed',
#  'after',
#  'afternoon',
#  'afterward',
#  'afterwards',
#  'again',
#  'against',
#  'age',
#  'ago',
#  'agonized',
#  'aim',
#  'albert',
#  'alert',
#  'algonquin',
#  'algonquins',
#  'all',
#  'allegations',
#  'alleged',
# ...

# %% [markdown]
# ###### Results

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(shortstory)
# Out:
# 0.1398820359717469

# %%
lexical_diversity(newsarticle)
# Out:
# 0.23835084513476473

# %% [markdown]
# ## 3. The longest sentence

# %%
shortstory_sentences = text.sents('PartyGirls.txt')

# %%
longest_len1 = max(len(s) for s in shortstory_sentences)
[s for s in shortstory_sentences if len(s) == longest_len1]
# Out:
# [['I',
#   'start',
#   'laughing',
#   'because',
#   'I',
#   'very',
#   'quickly',
#   'get',
#   'pins',
#   'and',
#   'needles',
#   'in',
#   'my',
#   'left',
#   'leg',
#   ',',
#   'so',
#   'we',
#   'move',
#   'around',
#   'and',
#   'I',
#   'end',
#   'up',
#   'sitting',
#   'on',
#   'her',
#   'lap',
#   ',',
#   'but',
#   'then',
#   'my',
#   'hair',
#   'gets',
#   'in',
#   'her',
#   'eyes',
#   ',',
#   'which',
#   'makes',
#   'her',
#   'laugh',
#   ',',
#   'so',
#   'she',
#   'ties',
#   'my',
#   'hair',
#   'up',
#   'with',
#   'a',
#   'spare',
#   'hairband',
#   'she',
#   'had',
#   'on',
#   'her',
#   'wrist',
#   'into',
#   'a',
#   'bun',
#   'on',
#   'the',
#   'top',
#   'of',
#   'my',
#   'head',
#   ',',
#   'which',
#   'makes',
#   'her',
#   'laugh',
#   'even',
#   'more',
#   ',',
#   'especially',
#   'while',
#   'I',
#   'sit',
#   'there',
#   'pulling',
#   'faces',
#   'and',
#   'asking',
#   'her',
#   'whether',
# ...

# %% [markdown]
# I start laughing because I very quickly get pins and needles in my left leg, so we move around and I end up sitting on her lap, but then my hair gets in her eyes, which makes her laugh, so she ties my hair up with a spare hairband she had on her wrist into a bun on the top of my head, which makes her laugh even more, especially while I sit there pulling faces and asking her whether she finds me attractive.

# %%
longest_len1
# Out:
# 91

# %%
newsarticle_sentences = text.sents('PretendianInvestigation.txt')

# %%
longest_len2 = max(len(s) for s in newsarticle_sentences)
[s for s in newsarticle_sentences if len(s) == longest_len2]
# Out:
# [['The',
#   'communications',
#   'department',
#   'sent',
#   'a',
#   'lengthy',
#   'statement',
#   ',',
#   'which',
#   'emphasized',
#   'its',
#   'general',
#   'commitment',
#   'to',
#   '“',
#   'reconciliation',
#   ',',
#   'Indigenization',
#   'and',
#   'decolonization',
#   '.”',
#   'As',
#   'for',
#   'Adams',
#   ',',
#   'the',
#   'statement',
#   'described',
#   'how',
#   'back',
#   'in',
#   '2019',
#   ',',
#   'Emily',
#   'Carr',
#   'was',
#   '“',
#   'confident',
#   'this',
#   'hiring',
#   'process',
#   'followed',
#   'best',
#   'practice',
#   'at',
#   'the',
#   'time',
#   '”',
#   'but',
#   'that',
#   '“',
#   'Maclean',
#   '’',
#   's',
#   'magazine',
#   'has',
#   'brought',
#   'forward',
#   'new',
#   'information',
#   'that',
#   'we',
#   'are',
#   'carefully',
#   'considering',
#   'as',
#   'we',
#   'determine',
#   'how',
#   'to',
#   'move',
#   'forward',
#   '.”',
#   'They',
#   'did',
#   'not',
#   'say',
# ...

# %% [markdown]
# The communications department sent a lengthy statement, which emphasized its general commitment to “reconciliation, Indigenization and decolonization.” As for Adams, the statement described how back in 2019, Emily Carr was “confident this hiring process followed best practice at the time” but that “Maclean’s magazine has brought forward new information that we are carefully considering as we determine how to move forward.” They did not say what information was new.

# %%
longest_len2
# Out:
# 82

# %% [markdown]
# ## 4. The top collocations

# %%
from nltk.probability import FreqDist

# %%
fdist1 = FreqDist(shortstory)

# %%
fdist1.most_common()
# Out:
# [('.', 780),
#  (',', 612),
#  ('I', 573),
#  ('’', 503),
#  ('“', 389),
#  ('to', 285),
#  ('the', 249),
#  ('and', 229),
#  ('a', 223),
#  ('.”', 175),
#  ('s', 166),
#  ('me', 156),
#  ('she', 148),
#  ('of', 145),
#  ('her', 138),
#  ('you', 131),
#  ('my', 127),
#  ('t', 127),
#  ('She', 116),
#  ('that', 112),
#  ('it', 100),
#  ('at', 94),
#  (',”', 89),
#  ('in', 89),
#  ('m', 85),
#  ('?”', 85),
#  ('with', 79),
#  ('like', 79),
#  ('just', 78),
#  ('out', 76),
#  ('is', 72),
#  ('for', 71),
#  ('we', 70),
#  ('don', 58),
#  ('be', 56),
#  ('says', 56),
#  ('?', 55),
#  ('say', 54),
#  ('have', 54),
#  ('on', 53),
#  ('up', 49),
#  ('re', 47),
#  ('so', 46),
#  ('-', 45),
#  ('It', 45),
#  ('ve', 44),
#  ('get', 44),
#  ('then', 44),
#  ('not', 44),
#  ('this', 44),
#  ('but', 41),
#  ('about', 40),
#  ('was', 39),
#  ('…', 39),
#  ('do', 38),
#  ('one', 37),
#  ('all', 35),
#  ('as', 34),
#  ('want', 34),
#  ('We', 33),
#  ('look', 32),
#  ('You', 32),
#  ('what', 31),
# ...

# %%
vowels = ['a','e','i','o','u']

# %%
print(vowels)
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
mostcom = []
for i in range(len(fdist1)):
       if fdist1[i] in vowels:
               {mostcom.append(fdist1[i])}

# %%
print(mostcom.append)
# Out:
# <built-in method append of list object at 0x000002472A129880>
